# %% [markdown]
# <a class="cbe-colab-launch" href="https://colab.research.google.com/github/tlliuca/AI4ChemEng/blob/main/dsmles/assignments/hw02-pandas-intro.ipynb" target="_blank" rel="noopener noreferrer" title="Open this notebook in Google Colab (opens in a new tab)">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" width="146" height="25">
# </a>

# %%
# Run this cell first in a fresh notebook environment.
# %pip install -q "numpy<2.4" pandas matplotlib scikit-learn pycse shap xgboost umap-learn jupyterquiz==2.9.6.2 uncertainties

# %%
# Included CBE4427/9133 data; no original-course server is contacted.
from pathlib import Path
import base64, json, tempfile, zlib
_course_embedded = json.loads(zlib.decompress(base64.b64decode('...')))
_course_cache = Path(tempfile.mkdtemp(prefix="cbe4427-"))
def course_file(name):
    """Use a local course file, or the copy embedded in this notebook."""
    for root in [Path.cwd(), *Path.cwd().parents]:
        for candidate in [root / "dsmles" / name, root / name]:
            if candidate.is_file():
                return str(candidate)
    if name not in _course_embedded:
        raise FileNotFoundError("Course resource not included: " + name)
    target = (_course_cache / name).resolve()
    if _course_cache not in target.parents:
        raise ValueError("Invalid course resource path")
    target.parent.mkdir(parents=True, exist_ok=True)
    if not target.exists():
        target.write_text(_course_embedded[name])
    return str(target)

# %% [markdown]
# ```{note}
# Tutorial resource for CBE4427/9133. Use this notebook for tutorial practice as directed by your instructor. The 13 tutorial notebooks are separate from the five assessed assignments. See [Course information](https://tlliuca.github.io/AI4ChemEng/course-information.html#assessment) for the undergraduate and graduate assessment requirements.
# ```

# %% [markdown]
# # Tutorial 2: Pandas Introduction
#
# Work through the exercises selected for your tutorial. Show your work and include comments explaining your approach.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1: DataFrame Basics
#
# Load and explore experiment data from a catalytic reactor study.

# %%
# Load experiment dataset from URL
url = course_file('data/hw02_experiments.csv')
experiments = pd.read_csv(url)

print(f"Loaded {len(experiments)} experiments")
experiments.head(10)

# %% [markdown]
# **1a.** How many experiments are missing conversion data? Which experiment IDs are missing this data?

# %%
# Your code here

# %% [markdown]
# **1b.** Use `.describe()` to get summary statistics for the numeric columns. What is the median pressure?

# %%
# Your code here

# %% [markdown]
# **1c.** Filter the DataFrame to show only experiments using Pt catalyst with temperature >= 400 K.

# %%
# Your code here

# %% [markdown]
# ## Problem 2: Data Manipulation
#
# Continue working with the experiments DataFrame.

# %% [markdown]
# **2a.** Calculate the average conversion and selectivity for each catalyst type using `.groupby()`.

# %%
# Your code here

# %% [markdown]
# **2b.** Add a new column called 'yield' calculated as conversion × selectivity.

# %%
# Your code here

# %% [markdown]
# **2c.** Find the top 5 experiments by yield. Display exp_id, catalyst, temperature, and yield.

# %%
# Your code here

# %% [markdown]
# **2d.** What is the average yield for each combination of catalyst and temperature? Use `.groupby()` with multiple columns.

# %%
# Your code here

# %% [markdown]
# ## Problem 3: Visualization
#
# Create visualizations to explore the data.

# %% [markdown]
# **3a.** Create a scatter plot of conversion vs temperature, colored by catalyst type.
#
# *Hint: You can loop through catalyst types and plot each separately with different colors, or use pandas plotting.*

# %%
# Your code here

# %% [markdown]
# **3b.** Create a box plot comparing conversion distributions across different catalysts.
#
# *Hint: Use `df.boxplot(column='conversion', by='catalyst')` or matplotlib.*

# %%
# Your code here

# %% [markdown]
# **3c.** Based on your analysis, which catalyst and temperature combination would you recommend for maximizing yield? Justify your answer with specific numbers from your analysis.

# %% [markdown]
# *Your answer here:*

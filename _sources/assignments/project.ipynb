# %% [markdown]
# <a class="cbe-colab-launch" href="https://colab.research.google.com/github/tlliuca/AI4ChemEng/blob/main/dsmles/assignments/project.ipynb" target="_blank" rel="noopener noreferrer" title="Open this notebook in Google Colab (opens in a new tab)">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" width="146" height="25">
# </a>

# %%
# Run this cell first in a fresh notebook environment.
# %pip install -q "numpy<2.4" pandas matplotlib scikit-learn pycse shap xgboost umap-learn jupyterquiz==2.9.6.2 uncertainties

# %%
# Included CBE4427/9133 data; no original-course server is contacted.
from pathlib import Path
import base64, json, tempfile, zlib
_course_embedded = json.loads(zlib.decompress(base64.b64decode('eNqrrgUAAXUA+Q==')))
_course_cache = Path(tempfile.mkdtemp(prefix="cbe4427-"))
def course_file(name):
    """Use a local course file, or the copy embedded in this notebook."""
    for root in [Path.cwd(), *Path.cwd().parents]:
        for candidate in [root / "dsmles" / name, root / name]:
            if candidate.is_file():
                return str(candidate)
    if name not in _course_embedded:
        raise FileNotFoundError("Course resource not included: " + name)
    target = (_course_cache / name).resolve()
    if _course_cache not in target.parents:
        raise ValueError("Invalid course resource path")
    target.parent.mkdir(parents=True, exist_ok=True)
    if not target.exists():
        target.write_text(_course_embedded[name])
    return str(target)

# %% [markdown]
# ```{note}
# Project planning resource for CBE4427/9133. The official course outline and instructor project brief govern assessment. Suggested structures and checklists do not add assessed components or marking criteria. See [Course information](https://tlliuca.github.io/AI4ChemEng/course-information.html#assessment) for the undergraduate and graduate assessment requirements.
# ```

# %% [markdown]
# # Course Project: AI in Chemical Engineering
#
# **CBE4427/9133**
#
# | Course | Project weight |
# |---|---|
# | Undergraduate (4427) | 50% of the final course grade; report and presentation combined |
# | Graduate (9133) | 60% of the final course grade: report 30% and presentation 30% |
#
# The undergraduate outline does not specify the report/presentation split. Follow the instructor's project brief for detailed component weights and marking criteria. See [Course information](https://tlliuca.github.io/AI4ChemEng/course-information.html#assessment) for the complete assessment summary.
#
# ## Overview
#
# Identify a complex, real-world problem in chemical engineering and develop an AI-based solution. Your work should include research, suitable data, model implementation, and a comprehensive analysis of the results. Explain the relevant engineering context, physical assumptions, and limitations, and communicate the innovative aspects of your solution.

# %% [markdown]
# ## Project Options
#
# ### Option A: Bring Your Own Data
# Use data from your research, internship, or a published paper. This is the preferred option as it connects to your own work.
#
# ### Option B: Public Dataset
# Use a publicly available dataset relevant to chemical engineering:
# - [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)
# - [Kaggle Datasets](https://www.kaggle.com/datasets)
# - [Materials Project](https://materialsproject.org/)
# - [NIST Chemistry WebBook](https://webbook.nist.gov/chemistry/)
#
# ### Example Topics
# - Predicting material properties from composition
# - Process optimization using surrogate models
# - Fault detection in manufacturing processes
# - Reaction yield prediction
# - Catalyst performance modeling
# - Polymer property prediction

# %% [markdown]
# ## Assessed project components
#
# ### Written report
# - Define and motivate the chemical engineering problem.
# - Describe the research background, data, and methods.
# - Present model implementation, results, and a comprehensive written analysis.
# - Explain engineering implications, innovative aspects, and limitations.
#
# ### Project presentation
# - Present the problem background, methodology, key findings, and innovative aspects in a research-seminar format.
# - Follow the instructor's instructions for presentation duration, questions, and required materials.
#
# ## Planning and feedback templates
#
# The proposal and progress check-in notebooks are available to help organize your work and obtain feedback when requested. They are not assigned separate course-grade weights in this book. Follow the project brief on OWL Brightspace for deadlines, required submissions, and marking criteria.

# %% [markdown]
# ## Suggested report structure
#
# Adapt this planning outline to the instructor's report requirements. Page lengths are suggestions, not assessment rules:
#
# ### 1. Introduction (1-2 pages)
# - Problem motivation
# - Background and prior work
# - Objectives
#
# ### 2. Data (1-2 pages)
# - Data source and collection
# - Feature descriptions
# - Exploratory data analysis
# - Preprocessing steps
#
# ### 3. Methods (2-3 pages)
# - Model selection rationale
# - Hyperparameter tuning approach
# - Validation strategy
#
# ### 4. Results (2-3 pages)
# - Model performance metrics
# - Comparison of methods
# - Feature importance / interpretability
# - Uncertainty quantification (if applicable)
#
# ### 5. Discussion (1-2 pages)
# - Key findings
# - Limitations
# - Future work
#
# ### 6. Conclusions (0.5 page)
# - Summary of contributions

# %% [markdown]
# ## Project planning checklist
#
# These prompts support preparation and self-review. They are not a separately weighted grading rubric; the instructor's project brief specifies the marking criteria.
#
# | Area | Questions to check |
# |---|---|
# | Problem and background | Is the real-world chemical engineering problem clearly motivated and grounded in relevant research? |
# | Data and implementation | Are the data suitable and the computational work reproducible? |
# | Methods and validation | Are the AI methods justified and evaluated appropriately? |
# | Results and analysis | Are results explained comprehensively, including uncertainty and limitations where relevant? |
# | Engineering interpretation | Are physical assumptions, practical implications, and innovative aspects discussed? |
# | Communication | Are the report and seminar presentation clear, well organized, and properly referenced? |

# %% [markdown]
# ## Tips for Success
#
# 1. **Start early** - Data collection and cleaning take time
# 2. **Iterate** - Don't expect perfect results on the first try
# 3. **Document everything** - Keep notes on what you tried
# 4. **Validate results** - Check if findings make physical sense
# 5. **Ask questions** - Office hours are there to help
# 6. **Focus on insight** - A simple model with good interpretation beats a complex black box

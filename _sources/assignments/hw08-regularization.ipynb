# %% [markdown]
# <a class="cbe-colab-launch" href="https://colab.research.google.com/github/tlliuca/AI4ChemEng/blob/main/dsmles/assignments/hw08-regularization.ipynb" target="_blank" rel="noopener noreferrer" title="Open this notebook in Google Colab (opens in a new tab)">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" width="146" height="25">
# </a>

# %%
# Run this cell first in a fresh notebook environment.
# %pip install -q "numpy<2.4" pandas matplotlib scikit-learn pycse shap xgboost umap-learn jupyterquiz==2.9.6.2 uncertainties

# %%
# Included CBE4427/9133 data; no original-course server is contacted.
from pathlib import Path
import base64, json, tempfile, zlib
_course_embedded = json.loads(zlib.decompress(base64.b64decode('...')))
_course_cache = Path(tempfile.mkdtemp(prefix="cbe4427-"))
def course_file(name):
    """Use a local course file, or the copy embedded in this notebook."""
    for root in [Path.cwd(), *Path.cwd().parents]:
        for candidate in [root / "dsmles" / name, root / name]:
            if candidate.is_file():
                return str(candidate)
    if name not in _course_embedded:
        raise FileNotFoundError("Course resource not included: " + name)
    target = (_course_cache / name).resolve()
    if _course_cache not in target.parents:
        raise ValueError("Invalid course resource path")
    target.parent.mkdir(parents=True, exist_ok=True)
    if not target.exists():
        target.write_text(_course_embedded[name])
    return str(target)

# %% [markdown]
# ```{note}
# Tutorial resource for CBE4427/9133. Use this notebook for tutorial practice as directed by your instructor. The 13 tutorial notebooks are separate from the five assessed assignments. See [Course information](https://tlliuca.github.io/AI4ChemEng/course-information.html#assessment) for the undergraduate and graduate assessment requirements.
# ```

# %% [markdown]
# # Tutorial 8: Regularization and Model Selection
#
# Apply regularization techniques and model selection strategies.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Problem 1: Overfitting Demonstration
#
# See how polynomial degree affects overfitting.

# %%
# Load polynomial data from URL
url = course_file('data/hw08_polynomial.csv')
poly_data = pd.read_csv(url)
X = poly_data['x'].values.reshape(-1, 1)
y = poly_data['y'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **1a.** Fit polynomial models of degree 1, 2, 5, and 15. Report train and test R² for each.

# %%
# Your code here

# %% [markdown]
# **1b.** Plot all four fitted curves on the same graph with the data. Which model overfits?

# %%
# Your code here

# %% [markdown]
# **1c.** What happens to the coefficient magnitudes as polynomial degree increases? Show examples.

# %%
# Your code here

# %% [markdown]
# ## Problem 2: Ridge and Lasso
#
# Apply regularization to a high-dimensional problem.

# %%
# Load sparse features data from URL
url = course_file('data/hw08_sparse_features.csv')
sparse_data = pd.read_csv(url)

# Extract features and target
feature_cols = [col for col in sparse_data.columns if col.startswith('feature_')]
X = sparse_data[feature_cols].values
y = sparse_data['target'].values
p = X.shape[1]
n = X.shape[0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Features: {p}, Samples: {n}")
print(f"True non-zero coefficients: 5 (first 5 features)")

# %% [markdown]
# **2a.** Fit ordinary linear regression. What is the test R²? How many coefficients are large (>0.1)?

# %%
# Your code here

# %% [markdown]
# **2b.** Use GridSearchCV to find the best alpha for Ridge regression (try alphas from 0.01 to 100). Report the best alpha and test R².

# %%
# Your code here

# %% [markdown]
# **2c.** Do the same for Lasso. How many coefficients are exactly zero?

# %%
# Your code here

# %% [markdown]
# **2d.** Compare the estimated coefficients from Lasso to the true coefficients. Did Lasso identify the correct features?

# %%
# Your code here

# %% [markdown]
# ## Problem 3: Model Selection
#
# **3a.** Plot the cross-validation score vs alpha for both Ridge and Lasso on the same graph. What do you observe?

# %%
# Your code here

# %% [markdown]
# **3b.** When would you choose Ridge over Lasso? When would you choose Lasso?

# %% [markdown]
# *Your answer here:*

# %% [markdown]
# **3c.** A colleague says "I got R²=0.99 on my training data, so my model is great!" What's wrong with this reasoning?

# %% [markdown]
# *Your answer here:*
